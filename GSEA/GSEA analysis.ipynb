# %%
import pandas as pd
import numpy as np
from math import sqrt
import copy
from collections import Counter

# %%
proto_gmt = pd.read_csv("data_for_gmt.csv")
gmt = proto_gmt.T
gmt
# Out:
#                                          0       1      2      3        4   \
# Telomere_attrition                      ATM    FEN1  SIRT1   TERC    TERF1
# Stem_cell_exhaustion                  FOXM1  MAPK14   PLAU  STAT3   STAT5A
# Mitochondrial_dysfunction              APTX   ATP5O    CAT   COQ7    HSPD1
# Genomic_instability                    ABL1   APEX1   BAK1    BLM     BMI1
# Epigenetic_alterations                 CDK1   CREB1  DDIT3   HBP1    HDAC1
# Deregulated_nutrient_sensing         AGPAT2    AKT1   APOE     AR    BSCL2
# Cellular_senescence                    ATF2     BAX   BMI1   BUB3   CREBBP
# Altered_intercellular_communication   AIFM1   APOC3     AR   BDNF  CACNA1A
# Loss_of_proteostasis                    A2M     APP   BCL2  BSCL2    DDIT3
#
#                                           5       6      7      8      9   \
# Telomere_attrition                     TERF2    TERT  XRCC6    NaN    NaN
# Stem_cell_exhaustion                     NaN     NaN    NaN    NaN    NaN
# Mitochondrial_dysfunction              IGF1R  MT-CO1   POLG  RAD51   RNTL
# Genomic_instability                    BRCA1   BRCA2  BUB1B  CCNA2   CDK1
# Epigenetic_alterations                 HDAC2   HMGB1  HMGB2    PML  PROP1
# Deregulated_nutrient_sensing         CACNA1A    DCY5  FGFR1  FOXO1    GH1
# Cellular_senescence                     CTGF    E2F1    EGF  EP300   EPOR
# Altered_intercellular_communication    CEBPA   CEBPB   EGFR   EGR1  ERBB2
# Loss_of_proteostasis                    EEF2   GSTA4  HSPA9   MAPT   MSRA
#
#                                      ...    53     54     55    56   57  \
# Telomere_attrition                   ...   NaN    NaN    NaN   NaN  NaN
# Stem_cell_exhaustion                 ...   NaN    NaN    NaN   NaN  NaN
# Mitochondrial_dysfunction            ...   NaN    NaN    NaN   NaN  NaN
# Genomic_instability                  ...  TOP1  TOP2A  TOP2B  TP53   TR
# Epigenetic_alterations               ...   NaN    NaN    NaN   NaN  NaN
# Deregulated_nutrient_sensing         ...   NaN    NaN    NaN   NaN  NaN
# Cellular_senescence                  ...   NaN    NaN    NaN   NaN  NaN
# Altered_intercellular_communication  ...   NaN    NaN    NaN   NaN  NaN
# Loss_of_proteostasis                 ...   NaN    NaN    NaN   NaN  NaN
#
#                                         58   59   60     61     62
# Telomere_attrition                     NaN  NaN  NaN    NaN    NaN
# Stem_cell_exhaustion                   NaN  NaN  NaN    NaN    NaN
# Mitochondrial_dysfunction              NaN  NaN  NaN    NaN    NaN
# Genomic_instability                  UCHL1  WRN  XPA  XRCC5  XRCC6
# Epigenetic_alterations                 NaN  NaN  NaN    NaN    NaN
# Deregulated_nutrient_sensing           NaN  NaN  NaN    NaN    NaN
# Cellular_senescence                    NaN  NaN  NaN    NaN    NaN
# Altered_intercellular_communication    NaN  NaN  NaN    NaN    NaN
# Loss_of_proteostasis                   NaN  NaN  NaN    NaN    NaN
#
# [9 rows x 63 columns]

# %%
expression = pd.read_csv("gene_expression_complete.csv", names = ['Gene', 'Expression'], skiprows = [0])
expression.head()
# Out:
#      Gene  Expression
# 0    TPT1   14.487080
# 1   RPL41   14.448307
# 2   HLA-A   14.415246
# 3  TMSB4X   14.405954
# 4   UBA52   14.400992

# %% [markdown]
# Now that we have a gmt file and a list of expression values, let's confirm that we can map from one to the other.

# %%
count = 0 
for i in gmt.iloc[3,:]:
    if i in set(expression.Gene):
        count += 1
        
print('So, ' + str(count) + ' of ')
# This is inelegant, as there are some NaN values, etc, but it confirms that our labels map.    
print(str(len(gmt.iloc[3,:])) + ' genes have mapped.')
# Out:
# So, 58 of
# 63 genes have mapped.

# %%
# Now we will try to do GSEA. Note that our 'expression' file is already ranked -- 
# it is a list of genes with their expression in treated relative to control, 
# ranked from highest to lowest expression

def calculate_enrichment_scores(expression, gmt):
    '''
    a function that calculates the enrichment score of a gene set in your expression data
    inputs: 
        expression data should be a list of gene ids, ordered by relative fold change between 
        treatment and control such that the gene with the greatest fold-change appears at the 
        top of the list and vice versa
        
        gmt_info should be your gmt file, parsed into a pandas DataFrame
        
    outputs:
        results, a DataFrame of gene set names and enrichment scores
        
    '''
    Enrichment_Score_dict = {}

    # for row in gmt
    for row in gmt.index:

        # find the geneset of interest; it is the intersection of the genes from the GMT file and the genes in the expression dataset
        full_gene_set = {x for x in gmt.loc[row,:] if pd.notna(x)}
        expression_set = set(expression.Gene) 
        gene_set = expression_set.intersection(full_gene_set)

        if len(gene_set) == 0:
            Enrichment_Score_dict[row] = 0
            print(str(row) + ' was 0')

        else: 
            # Now to set up our random walk penalties
            reward_amount = sqrt((len(expression) - len(gene_set))/(len(gene_set)))
            penalty_amount = -1 * sqrt(len(gene_set) / (len(expression) - len(gene_set)))
            # let's take a random walk
            expression = expression.assign(reward_or_penalty = [reward_amount if x in gene_set else penalty_amount for x in expression.Gene])
            expression = expression.assign(the_walk = np.cumsum(expression.reward_or_penalty))

            # now let's check that the random walk ends with a zero (as it should)
            if int(expression.the_walk.tail(1)) != 0:
                print(int(expression.the_walk.tail(1)))
                raise ValueError("your brownian bridge is broken")  ## just checking

            Enrichment_Score_dict[row] = round(max(expression.the_walk),2)

    results = pd.DataFrame.from_dict(Enrichment_Score_dict, orient = 'index', columns = ['Enrichment_Score'])
    return(results)

results = calculate_enrichment_scores(expression, gmt)    
print(results)
# Out:
#                                      Enrichment_Score
# Telomere_attrition                             142.03
# Stem_cell_exhaustion                            86.22
# Mitochondrial_dysfunction                      222.73
# Genomic_instability                            243.03
# Epigenetic_alterations                         120.60
# Deregulated_nutrient_sensing                   130.65
# Cellular_senescence                            206.86
# Altered_intercellular_communication            188.48
# Loss_of_proteostasis                           257.67

# %% [markdown]
# Now we need to find a critical threshold value to decide what constitutes statistically significant enrichment.
# We will do this empirically by generating random data and observing the fraction of times we obtain a value greater than our true values by chance alone.

# %%
def emperic_p_values(expression, gmt, res, n_iterations):

    distribution = copy.copy(res)
    for i in range(n_iterations):
        pretend_ranked_list = pd.DataFrame(expression.Gene.sample(frac = 1))
        rando_scores = calculate_enrichment_scores(pretend_ranked_list, gmt)
        distribution = pd.concat([distribution, rando_scores], axis = 1)
    
    raw_p = {}
    corrected_p = {}

    # take each set of enrichment scores - the first is our result, the others occured by chance alone
    for k in distribution.index:
        list_of_values = list(distribution.loc[k,:])
        number_greater = 0
        for l in list_of_values[1:]:
            if l >= list_of_values[0]:
                number_greater += 1
        # the raw p value is the fraction of randomly generated enrichment scores that were equal to or greater than our result        
        raw_p[k] = (float(number_greater)/float(len(list_of_values[1:])))

    p_values = pd.DataFrame.from_dict(raw_p, orient = 'index', columns = ['Raw_p_value'])

    # now we can correct for multiple testing by determining an appropriate p value threshold with Bonferroni correction
    p_values = p_values.assign(p_value_threshold = 0.05 / distribution.shape[0])
    p_values = p_values.assign(Significantly_enriched = p_values.Raw_p_value <= p_values.p_value_threshold)
    return(p_values)

# %%
emperic_p_values(expression, gmt,results, 1000)
# Out:
#                                      Raw_p_value  p_value_threshold  \
# Telomere_attrition                         0.064           0.005556
# Stem_cell_exhaustion                       0.348           0.005556
# Mitochondrial_dysfunction                  0.002           0.005556
# Genomic_instability                        0.002           0.005556
# Epigenetic_alterations                     0.155           0.005556
# Deregulated_nutrient_sensing               0.118           0.005556
# Cellular_senescence                        0.003           0.005556
# Altered_intercellular_communication        0.007           0.005556
# Loss_of_proteostasis                       0.001           0.005556
#
#                                      Significantly_enriched
# Telomere_attrition                                    False
# Stem_cell_exhaustion                                  False
# Mitochondrial_dysfunction                              True
# Genomic_instability                                    True
# Epigenetic_alterations                                False
# Deregulated_nutrient_sensing                          False
# Cellular_senescence                                    True
# Altered_intercellular_communication                   False
# Loss_of_proteostasis                                   True

# %% [markdown]
# Now, as a comparison, let's perform GSEA using canonical KEGG pathways. I will need a bit of code to parse the KEGG file.

# %%
kegg_gmt_dict = {}
with open('c2.cp.kegg.v6.2.symbols.gmt') as f:
    for line in f:
        line_bits = line.split()
        kegg_gmt_dict[line_bits[0]] = line_bits[1:]

kegg_gmt_frame = pd.DataFrame.from_dict(kegg_gmt_dict, orient='index' )
kegg_gmt = kegg_gmt_frame.iloc[:, 1:]

# %%
kegg_results = calculate_enrichment_scores(expression, kegg_gmt)    
print(kegg_results)
# Out:
#                                                     Enrichment_Score
# KEGG_GLYCOLYSIS_GLUCONEOGENESIS                               210.27
# KEGG_CITRATE_CYCLE_TCA_CYCLE                                  334.74
# KEGG_PENTOSE_PHOSPHATE_PATHWAY                                230.16
# KEGG_PENTOSE_AND_GLUCURONATE_INTERCONVERSIONS                  33.88
# KEGG_FRUCTOSE_AND_MANNOSE_METABOLISM                          240.10
# KEGG_GALACTOSE_METABOLISM                                     198.41
# KEGG_ASCORBATE_AND_ALDARATE_METABOLISM                         28.75
# KEGG_FATTY_ACID_METABOLISM                                    172.55
# KEGG_STEROID_BIOSYNTHESIS                                     114.66
# KEGG_PRIMARY_BILE_ACID_BIOSYNTHESIS                            47.12
# KEGG_STEROID_HORMONE_BIOSYNTHESIS                              33.05
# KEGG_OXIDATIVE_PHOSPHORYLATION                                572.66
# KEGG_PURINE_METABOLISM                                        225.94
# KEGG_PYRIMIDINE_METABOLISM                                    328.08
# KEGG_ALANINE_ASPARTATE_AND_GLUTAMATE_METABOLISM                95.56
# KEGG_GLYCINE_SERINE_AND_THREONINE_METABOLISM                    1.75
# KEGG_CYSTEINE_AND_METHIONINE_METABOLISM                       132.27
# KEGG_VALINE_LEUCINE_AND_ISOLEUCINE_DEGRADATION                254.73
# KEGG_VALINE_LEUCINE_AND_ISOLEUCINE_BIOSYNTHESIS               149.71
# KEGG_LYSINE_DEGRADATION                                       174.10
# KEGG_ARGININE_AND_PROLINE_METABOLISM                           84.82
# KEGG_HISTIDINE_METABOLISM                                      62.50
# KEGG_TYROSINE_METABOLISM                                       47.45
# KEGG_PHENYLALANINE_METABOLISM                                  41.55
# KEGG_TRYPTOPHAN_METABOLISM                                    113.15
# KEGG_BETA_ALANINE_METABOLISM                                  102.75
# KEGG_TAURINE_AND_HYPOTAURINE_METABOLISM                        29.50
# KEGG_SELENOAMINO_ACID_METABOLISM                              149.81
# KEGG_GLUTATHIONE_METABOLISM                                   210.19
# KEGG_STARCH_AND_SUCROSE_METABOLISM                             71.15
# ...                                                              ...
# KEGG_PRION_DISEASES                                           200.40
# KEGG_VIBRIO_CHOLERAE_INFECTION                                284.10
# KEGG_EPITHELIAL_CELL_SIGNALING_IN_HELICOBACTER_...            289.65
# KEGG_PATHOGENIC_ESCHERICHIA_COLI_INFECTION                    404.20
# KEGG_LEISHMANIA_INFECTION                                     406.42
# KEGG_PATHWAYS_IN_CANCER                                       289.80
# KEGG_COLORECTAL_CANCER                                        269.03
# KEGG_RENAL_CELL_CARCINOMA                                     267.78
# KEGG_PANCREATIC_CANCER                                        286.59
# KEGG_ENDOMETRIAL_CANCER                                       239.65
# KEGG_GLIOMA                                                   220.93
# KEGG_PROSTATE_CANCER                                          267.54
# KEGG_THYROID_CANCER                                           188.23
# KEGG_BASAL_CELL_CARCINOMA                                      10.79
# KEGG_MELANOMA                                                  67.07
# KEGG_BLADDER_CANCER                                           135.74
# KEGG_CHRONIC_MYELOID_LEUKEMIA                                 351.69
# KEGG_ACUTE_MYELOID_LEUKEMIA                                   308.81
# KEGG_SMALL_CELL_LUNG_CANCER                                   192.70
# KEGG_NON_SMALL_CELL_LUNG_CANCER                               252.78
# KEGG_ASTHMA                                                   188.65
# KEGG_AUTOIMMUNE_THYROID_DISEASE                               217.89
# KEGG_SYSTEMIC_LUPUS_ERYTHEMATOSUS                             113.08
# KEGG_ALLOGRAFT_REJECTION                                      265.35
# KEGG_GRAFT_VERSUS_HOST_DISEASE                                304.81
# KEGG_PRIMARY_IMMUNODEFICIENCY                                 254.20
# KEGG_HYPERTROPHIC_CARDIOMYOPATHY_HCM                           45.50
# KEGG_ARRHYTHMOGENIC_RIGHT_VENTRICULAR_CARDIOMYO...             83.80
# KEGG_DILATED_CARDIOMYOPATHY                                    46.55
# KEGG_VIRAL_MYOCARDITIS                                        285.89
#
# [186 rows x 1 columns]

# %%
kegg_p_values = emperic_p_values(expression, kegg_gmt, kegg_results, 100)
kegg_p_values[kegg_p_values.Significantly_enriched == True]
# Out:
#                                                     Raw_p_value  \
# KEGG_GLYCOLYSIS_GLUCONEOGENESIS                             0.0
# KEGG_CITRATE_CYCLE_TCA_CYCLE                                0.0
# KEGG_PENTOSE_PHOSPHATE_PATHWAY                              0.0
# KEGG_FRUCTOSE_AND_MANNOSE_METABOLISM                        0.0
# KEGG_GALACTOSE_METABOLISM                                   0.0
# KEGG_OXIDATIVE_PHOSPHORYLATION                              0.0
# KEGG_PURINE_METABOLISM                                      0.0
# KEGG_PYRIMIDINE_METABOLISM                                  0.0
# KEGG_VALINE_LEUCINE_AND_ISOLEUCINE_DEGRADATION              0.0
# KEGG_GLUTATHIONE_METABOLISM                                 0.0
# KEGG_N_GLYCAN_BIOSYNTHESIS                                  0.0
# KEGG_OTHER_GLYCAN_DEGRADATION                               0.0
# KEGG_AMINO_SUGAR_AND_NUCLEOTIDE_SUGAR_METABOLISM            0.0
# KEGG_INOSITOL_PHOSPHATE_METABOLISM                          0.0
# KEGG_GLYCOSYLPHOSPHATIDYLINOSITOL_GPI_ANCHOR_BI...          0.0
# KEGG_PROPANOATE_METABOLISM                                  0.0
# KEGG_TERPENOID_BACKBONE_BIOSYNTHESIS                        0.0
# KEGG_AMINOACYL_TRNA_BIOSYNTHESIS                            0.0
# KEGG_RIBOSOME                                               0.0
# KEGG_RNA_DEGRADATION                                        0.0
# KEGG_RNA_POLYMERASE                                         0.0
# KEGG_BASAL_TRANSCRIPTION_FACTORS                            0.0
# KEGG_DNA_REPLICATION                                        0.0
# KEGG_SPLICEOSOME                                            0.0
# KEGG_PROTEASOME                                             0.0
# KEGG_PROTEIN_EXPORT                                         0.0
# KEGG_BASE_EXCISION_REPAIR                                   0.0
# KEGG_NUCLEOTIDE_EXCISION_REPAIR                             0.0
# KEGG_MISMATCH_REPAIR                                        0.0
# KEGG_MAPK_SIGNALING_PATHWAY                                 0.0
# ...                                                         ...
# KEGG_LONG_TERM_POTENTIATION                                 0.0
# KEGG_NEUROTROPHIN_SIGNALING_PATHWAY                         0.0
# KEGG_REGULATION_OF_ACTIN_CYTOSKELETON                       0.0
# KEGG_INSULIN_SIGNALING_PATHWAY                              0.0
# KEGG_ADIPOCYTOKINE_SIGNALING_PATHWAY                        0.0
# KEGG_TYPE_I_DIABETES_MELLITUS                               0.0
# KEGG_VASOPRESSIN_REGULATED_WATER_REABSORPTION               0.0
# KEGG_ALZHEIMERS_DISEASE                                     0.0
# KEGG_PARKINSONS_DISEASE                                     0.0
# KEGG_HUNTINGTONS_DISEASE                                    0.0
# KEGG_PRION_DISEASES                                         0.0
# KEGG_VIBRIO_CHOLERAE_INFECTION                              0.0
# KEGG_EPITHELIAL_CELL_SIGNALING_IN_HELICOBACTER_...          0.0
# KEGG_PATHOGENIC_ESCHERICHIA_COLI_INFECTION                  0.0
# KEGG_LEISHMANIA_INFECTION                                   0.0
# KEGG_PATHWAYS_IN_CANCER                                     0.0
# KEGG_COLORECTAL_CANCER                                      0.0
# KEGG_RENAL_CELL_CARCINOMA                                   0.0
# KEGG_PANCREATIC_CANCER                                      0.0
# KEGG_ENDOMETRIAL_CANCER                                     0.0
# KEGG_GLIOMA                                                 0.0
# KEGG_PROSTATE_CANCER                                        0.0
# KEGG_CHRONIC_MYELOID_LEUKEMIA                               0.0
# KEGG_ACUTE_MYELOID_LEUKEMIA                                 0.0
# KEGG_NON_SMALL_CELL_LUNG_CANCER                             0.0
# KEGG_AUTOIMMUNE_THYROID_DISEASE                             0.0
# KEGG_ALLOGRAFT_REJECTION                                    0.0
# KEGG_GRAFT_VERSUS_HOST_DISEASE                              0.0
# KEGG_PRIMARY_IMMUNODEFICIENCY                               0.0
# KEGG_VIRAL_MYOCARDITIS                                      0.0
#
#                                                     p_value_threshold  \
# KEGG_GLYCOLYSIS_GLUCONEOGENESIS                              0.000269
# KEGG_CITRATE_CYCLE_TCA_CYCLE                                 0.000269
# KEGG_PENTOSE_PHOSPHATE_PATHWAY                               0.000269
# KEGG_FRUCTOSE_AND_MANNOSE_METABOLISM                         0.000269
# KEGG_GALACTOSE_METABOLISM                                    0.000269
# KEGG_OXIDATIVE_PHOSPHORYLATION                               0.000269
# KEGG_PURINE_METABOLISM                                       0.000269
# KEGG_PYRIMIDINE_METABOLISM                                   0.000269
# KEGG_VALINE_LEUCINE_AND_ISOLEUCINE_DEGRADATION               0.000269
# KEGG_GLUTATHIONE_METABOLISM                                  0.000269
# KEGG_N_GLYCAN_BIOSYNTHESIS                                   0.000269
# KEGG_OTHER_GLYCAN_DEGRADATION                                0.000269
# KEGG_AMINO_SUGAR_AND_NUCLEOTIDE_SUGAR_METABOLISM             0.000269
# KEGG_INOSITOL_PHOSPHATE_METABOLISM                           0.000269
# KEGG_GLYCOSYLPHOSPHATIDYLINOSITOL_GPI_ANCHOR_BI...           0.000269
# KEGG_PROPANOATE_METABOLISM                                   0.000269
# KEGG_TERPENOID_BACKBONE_BIOSYNTHESIS                         0.000269
# KEGG_AMINOACYL_TRNA_BIOSYNTHESIS                             0.000269
# KEGG_RIBOSOME                                                0.000269
# KEGG_RNA_DEGRADATION                                         0.000269
# KEGG_RNA_POLYMERASE                                          0.000269
# KEGG_BASAL_TRANSCRIPTION_FACTORS                             0.000269
# KEGG_DNA_REPLICATION                                         0.000269
# KEGG_SPLICEOSOME                                             0.000269
# KEGG_PROTEASOME                                              0.000269
# KEGG_PROTEIN_EXPORT                                          0.000269
# KEGG_BASE_EXCISION_REPAIR                                    0.000269
# KEGG_NUCLEOTIDE_EXCISION_REPAIR                              0.000269
# KEGG_MISMATCH_REPAIR                                         0.000269
# KEGG_MAPK_SIGNALING_PATHWAY                                  0.000269
# ...                                                               ...
# KEGG_LONG_TERM_POTENTIATION                                  0.000269
# KEGG_NEUROTROPHIN_SIGNALING_PATHWAY                          0.000269
# KEGG_REGULATION_OF_ACTIN_CYTOSKELETON                        0.000269
# KEGG_INSULIN_SIGNALING_PATHWAY                               0.000269
# KEGG_ADIPOCYTOKINE_SIGNALING_PATHWAY                         0.000269
# KEGG_TYPE_I_DIABETES_MELLITUS                                0.000269
# KEGG_VASOPRESSIN_REGULATED_WATER_REABSORPTION                0.000269
# KEGG_ALZHEIMERS_DISEASE                                      0.000269
# KEGG_PARKINSONS_DISEASE                                      0.000269
# KEGG_HUNTINGTONS_DISEASE                                     0.000269
# KEGG_PRION_DISEASES                                          0.000269
# KEGG_VIBRIO_CHOLERAE_INFECTION                               0.000269
# KEGG_EPITHELIAL_CELL_SIGNALING_IN_HELICOBACTER_...           0.000269
# KEGG_PATHOGENIC_ESCHERICHIA_COLI_INFECTION                   0.000269
# KEGG_LEISHMANIA_INFECTION                                    0.000269
# KEGG_PATHWAYS_IN_CANCER                                      0.000269
# KEGG_COLORECTAL_CANCER                                       0.000269
# KEGG_RENAL_CELL_CARCINOMA                                    0.000269
# KEGG_PANCREATIC_CANCER                                       0.000269
# KEGG_ENDOMETRIAL_CANCER                                      0.000269
# KEGG_GLIOMA                                                  0.000269
# KEGG_PROSTATE_CANCER                                         0.000269
# KEGG_CHRONIC_MYELOID_LEUKEMIA                                0.000269
# KEGG_ACUTE_MYELOID_LEUKEMIA                                  0.000269
# KEGG_NON_SMALL_CELL_LUNG_CANCER                              0.000269
# KEGG_AUTOIMMUNE_THYROID_DISEASE                              0.000269
# KEGG_ALLOGRAFT_REJECTION                                     0.000269
# KEGG_GRAFT_VERSUS_HOST_DISEASE                               0.000269
# KEGG_PRIMARY_IMMUNODEFICIENCY                                0.000269
# KEGG_VIRAL_MYOCARDITIS                                       0.000269
#
#                                                     Significantly_enriched
# KEGG_GLYCOLYSIS_GLUCONEOGENESIS                                       True
# KEGG_CITRATE_CYCLE_TCA_CYCLE                                          True
# KEGG_PENTOSE_PHOSPHATE_PATHWAY                                        True
# KEGG_FRUCTOSE_AND_MANNOSE_METABOLISM                                  True
# KEGG_GALACTOSE_METABOLISM                                             True
# KEGG_OXIDATIVE_PHOSPHORYLATION                                        True
# KEGG_PURINE_METABOLISM                                                True
# KEGG_PYRIMIDINE_METABOLISM                                            True
# KEGG_VALINE_LEUCINE_AND_ISOLEUCINE_DEGRADATION                        True
# KEGG_GLUTATHIONE_METABOLISM                                           True
# KEGG_N_GLYCAN_BIOSYNTHESIS                                            True
# KEGG_OTHER_GLYCAN_DEGRADATION                                         True
# KEGG_AMINO_SUGAR_AND_NUCLEOTIDE_SUGAR_METABOLISM                      True
# KEGG_INOSITOL_PHOSPHATE_METABOLISM                                    True
# KEGG_GLYCOSYLPHOSPHATIDYLINOSITOL_GPI_ANCHOR_BI...                    True
# KEGG_PROPANOATE_METABOLISM                                            True
# KEGG_TERPENOID_BACKBONE_BIOSYNTHESIS                                  True
# KEGG_AMINOACYL_TRNA_BIOSYNTHESIS                                      True
# KEGG_RIBOSOME                                                         True
# KEGG_RNA_DEGRADATION                                                  True
# KEGG_RNA_POLYMERASE                                                   True
# KEGG_BASAL_TRANSCRIPTION_FACTORS                                      True
# KEGG_DNA_REPLICATION                                                  True
# KEGG_SPLICEOSOME                                                      True
# KEGG_PROTEASOME                                                       True
# KEGG_PROTEIN_EXPORT                                                   True
# KEGG_BASE_EXCISION_REPAIR                                             True
# KEGG_NUCLEOTIDE_EXCISION_REPAIR                                       True
# KEGG_MISMATCH_REPAIR                                                  True
# KEGG_MAPK_SIGNALING_PATHWAY                                           True
# ...                                                                    ...
# KEGG_LONG_TERM_POTENTIATION                                           True
# KEGG_NEUROTROPHIN_SIGNALING_PATHWAY                                   True
# KEGG_REGULATION_OF_ACTIN_CYTOSKELETON                                 True
# KEGG_INSULIN_SIGNALING_PATHWAY                                        True
# KEGG_ADIPOCYTOKINE_SIGNALING_PATHWAY                                  True
# KEGG_TYPE_I_DIABETES_MELLITUS                                         True
# KEGG_VASOPRESSIN_REGULATED_WATER_REABSORPTION                         True
# KEGG_ALZHEIMERS_DISEASE                                               True
# KEGG_PARKINSONS_DISEASE                                               True
# KEGG_HUNTINGTONS_DISEASE                                              True
# KEGG_PRION_DISEASES                                                   True
# KEGG_VIBRIO_CHOLERAE_INFECTION                                        True
# KEGG_EPITHELIAL_CELL_SIGNALING_IN_HELICOBACTER_...                    True
# KEGG_PATHOGENIC_ESCHERICHIA_COLI_INFECTION                            True
# KEGG_LEISHMANIA_INFECTION                                             True
# KEGG_PATHWAYS_IN_CANCER                                               True
# KEGG_COLORECTAL_CANCER                                                True
# KEGG_RENAL_CELL_CARCINOMA                                             True
# KEGG_PANCREATIC_CANCER                                                True
# KEGG_ENDOMETRIAL_CANCER                                               True
# KEGG_GLIOMA                                                           True
# KEGG_PROSTATE_CANCER                                                  True
# KEGG_CHRONIC_MYELOID_LEUKEMIA                                         True
# KEGG_ACUTE_MYELOID_LEUKEMIA                                           True
# KEGG_NON_SMALL_CELL_LUNG_CANCER                                       True
# KEGG_AUTOIMMUNE_THYROID_DISEASE                                       True
# KEGG_ALLOGRAFT_REJECTION                                              True
# KEGG_GRAFT_VERSUS_HOST_DISEASE                                        True
# KEGG_PRIMARY_IMMUNODEFICIENCY                                         True
# KEGG_VIRAL_MYOCARDITIS                                                True
#
# [84 rows x 3 columns]
